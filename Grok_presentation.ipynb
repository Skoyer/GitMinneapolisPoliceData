# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.shapes import MSO_SHAPE
from pptx.dml.color import RGBColor
from pptx.enum.text import MSO_ANCHOR, PP_ALIGN
from pptx.enum.chart import XL_CHART_TYPE, XL_LEGEND_POSITION

# Create a presentation
prs = Presentation()

# Title Slide
slide_layout = prs.slide_layouts[0]
slide = prs.slides.add_slide(slide_layout)

# Add title and subtitle to the title slide
title = slide.shapes.title
subtitle = slide.placeholders[1]

title.text = "Collaborative Data Science Projects: Enhancing Learning and Research"
subtitle.text = "Presentation by [Your Name]\nDate: October 8, 2024"

# Introduction Slide
slide_layout = prs.slide_layouts[1]
slide = prs.slides.add_slide(slide_layout)

# Add title and content to the introduction slide
title = slide.shapes.title
content = slide.placeholders[1]

title.text = "Introduction"
content.text = (
    "Objective: Introduce the concept of structured, weekly collaborative projects.\n\n"
    "Why Collaboration?\n"
    "- Enhances learning through diverse perspectives.\n"
    "- Promotes problem-solving skills.\n"
    "- Prepares for industry or academic team environments."
)

# Slide 3 to Slide 11 (you can follow a similar pattern for each slide)
# Here's a generic loop to add the remaining slides with titles and content:

slide_content = [
    ("Project Structure", 
     "Frequency: Weekly projects to keep momentum and learning continuous.\n"
     "Duration: Each project could span a week or two, depending on complexity.\n"
     "Roles: Rotate roles like project lead, data analyst, methodologist, communicator, etc."),
    ("Project Selection", 
     "Method: Voting system for project topics.\n"
     "Criteria: Relevance to current studies, feasibility within the timeframe, learning potential."),
    ("Team Assessment and Surveys", 
     "Learning from Terri: Highlight her expertise in surveys and assessments.\n"
     "Types of Surveys:\n- Pre-project surveys to gauge interest and background.\n- Mid-project feedback for adjustments.\n- Post-project review for learning outcomes and satisfaction."),
    ("Feedback Channels", 
     "Professional Feedback:\n- Use tools like Slack, Microsoft Teams, or a designated forum.\n- Set guidelines for constructive criticism.\n"
     "Respectful Communication: Emphasize the importance of professionalism and respect."),
    ("Inclusivity and Confidence Building", 
     "Strategies for Inclusivity:\n- Ensure quiet voices are heard through structured rounds of feedback.\n- Pair more confident members with less confident ones for mutual learning.\n"
     "Confidence Building:\n- Celebrate small wins.\n- Provide platforms for presentation and peer review."),
    ("Case Study or Example Project", 
     "Brief Overview: Show a past project or hypothetical example.\n"
     "What Worked: Highlight successful collaboration points.\n"
     "Learning Points: Areas where improvements were made."),
    ("Tools and Resources", 
     "Software: Mention tools like Jupyter Notebooks, GitHub for version control, etc.\n"
     "Learning Platforms: Links to online courses or resources for mastering necessary skills."),
    ("Conclusion", 
     "Recap: The benefits of structured collaboration.\n"
     "Future Steps: Encourage continuous improvement, maybe consider a project showcase or conference."),
    ("Q&A", "Invite questions from the audience.")
]

for title_text, content_text in slide_content:
    slide_layout = prs.slide_layouts[1]  # Assuming Title and Content layout
    slide = prs.slides.add_slide(slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = title_text
    content.text = content_text

# Save the presentation
filename = "Collaborative_Data_Science_Projects_Demo.pptx"
prs.save(filename)
print(f"PowerPoint presentation saved as {filename}")
# Out:
# PowerPoint presentation saved as Collaborative_Data_Science_Projects_Demo.pptx
