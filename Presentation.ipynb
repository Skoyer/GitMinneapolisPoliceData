# %%
import pandas as pd
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.text import PP_ALIGN

# Create presentation object
prs = Presentation()

# Title Slide
slide_layout = prs.slide_layouts[0]  # 0 is for title slides
slide = prs.slides.add_slide(slide_layout)
title = slide.shapes.title
subtitle = slide.placeholders[1]

title.text = "Creating Weekly Collaborative Data Science Projects"
subtitle.text = "By [Your Name]"

# Slide 1: Introduction
slide_layout = prs.slide_layouts[1]  # 1 is for title and content slides
slide = prs.slides.add_slide(slide_layout)
title = slide.shapes.title
title.text = "Introduction: The Importance of Collaboration"

content = slide.shapes.placeholders[1].text_frame
content.text = ("Collaboration in Data Science enhances:\n"
                "- Problem-solving through diverse perspectives\n"
                "- Hands-on experience with real-world data\n"
                "- Development of teamwork and communication skills\n"
                "This presentation covers how to organize and foster weekly collaboration among Masters and PhD students.")

# Slide 2: Objective of Weekly Collaborative Projects
slide = prs.slides.add_slide(slide_layout)
title = slide.shapes.title
title.text = "Objective of Weekly Collaborative Projects"

content = slide.shapes.placeholders[1].text_frame
content.text = ("Key Objectives:\n"
                "- Solve real-world data problems\n"
                "- Practice data science tools and techniques\n"
                "- Foster an inclusive environment for collaboration and growth\n"
                "- Develop both technical and soft skills.")

# Slide 3: How to Organize Weekly Projects
slide = prs.slides.add_slide(slide_layout)
title = slide.shapes.title
title.text = "How to Organize Weekly Projects"

content = slide.shapes.placeholders[1].text_frame
content.text = ("1. Define weekly project tasks: problem framing, data collection, modeling.\n"
                "2. Assign team members different roles to ensure balanced learning.\n"
                "3. Rotate topics based on team interests (use surveys/voting).\n"
                "4. Use tools like GitHub, Google Colab, and Slack for collaboration.")

# Slide 4: Team Dynamics and Group Management
slide = prs.slides.add_slide(slide_layout)
title = slide.shapes.title
title.text = "Team Dynamics and Group Management"

content = slide.shapes.placeholders[1].text_frame
content.text = ("1. Structured Feedback Channels:\n"
                "- Create a professional and respectful feedback space (e.g., Google Doc, Slack).\n"
                "2. Inclusivity and Confidence Building:\n"
                "- Rotate leadership roles to empower all members.\n"
                "- Use peer mentoring and celebrate contributions.\n"
                "3. Use weekly surveys to gather anonymous feedback.")

# Slide 5: Tools for Assessment and Feedback
slide = prs.slides.add_slide(slide_layout)
title = slide.shapes.title
title.text = "Tools for Assessment and Feedback"

content = slide.shapes.placeholders[1].text_frame
content.text = ("1. Terri’s Approach to Team Assessments:\n"
                "- Leverage Terri's techniques for gathering honest, respectful feedback.\n"
                "2. Use Tools like Google Forms and SurveyMonkey for assessments.\n"
                "3. Use quick pulse checks weekly to gauge group satisfaction and identify areas of improvement.")

# Slide 6: Proposed Weekly Workflow
slide = prs.slides.add_slide(slide_layout)
title = slide.shapes.title
title.text = "Proposed Weekly Workflow"

content = slide.shapes.placeholders[1].text_frame
content.text = ("Week 1: Problem Framing & Data Understanding\n"
                "Week 2: Exploratory Data Analysis & Preprocessing\n"
                "Week 3: Model Building & Feature Engineering\n"
                "Week 4: Model Evaluation & Reporting\n"
                "Include reflective surveys after each week for assessment and improvement.")

# Slide 7: Final Reflection and Takeaways
slide = prs.slides.add_slide(slide_layout)
title = slide.shapes.title
title.text = "Final Reflection and Takeaways"

content = slide.shapes.placeholders[1].text_frame
content.text = ("- Collaboration enhances technical and soft skills.\n"
                "- Inclusive teamwork promotes growth and confidence for all members.\n"
                "- Constructive, respectful feedback is key to continuous improvement.\n"
                "Encourage ongoing collaboration and learning beyond the classroom!")

# Save the presentation
pptx_file = "./ChatGPT_Collaborative_Data_Science_Projects_Presentation.pptx"
prs.save(pptx_file)

pptx_file
# Out:
# './ChatGPT_Collaborative_Data_Science_Projects_Presentation.pptx'
